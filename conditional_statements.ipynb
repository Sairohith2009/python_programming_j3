# %% [markdown]
# # conditional statements in python
# 1. Python have 4 types of conditional statements
# 2. `if` statement
# 3. `elif` statement
# 4. `else` statement
# 5. `nested` statements
#
# ```python
# if(condition);
#    statements
#    statements..
# ```
#
# ```python if
# if(condition);
#    statements
#    statements...
# else:
#     statements
#     statements...
# ```
#
# ```python if,elif,else
# if(condition);
#    statement
# elif(condition);
#    statements
# else:
#     statement..
# ```

# %%
# write a program to find the given number is even number
num=int(input("please enter number here:"))
if(num%2 == 0):
    print(num,"is even number")
# Out:
# please enter number here: 100
# 100 is even number

# %%
10%2
# Out:
# 0

# %%
# write a program to find the given number is even number or odd number
number=int(input("please enter number here:"))
if(number%2 == 0):
    print(number,"is even number")
else:
    print(number,"is odd number")
# Out:
# please enter number here: 58896
# 58896 is even number

# %%
# write a program to find the given number is even number or odd number
number=int(input("please enter number here:"))
if(number%2 == 0):
    print(number,"is even number")
else:
    print(number,"is odd number")
# Out:
# please enter number here: 78789
# 78789 is odd number

# %%
# write a program to find whether a number is positive,negative or zero
number=int(input("please enter a number here:"))
if(number>0):
   print(number,"is a positive number")
elif(number<0):
   print(number,"is a negative number")
else:
   print(number,"is zero")
# Out:
# please enter a number here: 4
# 4 is a positive number

# %%
# write a program to find whether a number is positive,negative or zero
number=int(input("please enter a number here:"))
if(number>0):
   print(number,"is a positive number")
elif(number<0):
   print(number,"is a negative number")
else:
   print(number,"is zero")
# Out:
# please enter a number here: -9
# -9 is a negative number

# %%
# write a program to find whether a number is positive,negative or zero
number=int(input("please enter a number here:"))
if(number>0):
   print(number,"is a positive number")
elif(number<0):
   print(number,"is a negative number")
else:
   print(number,"is zero")
# Out:
# please enter a number here: 0
# 0 is zero

# %%
"""
# write a program to find the student grades based on marks
1. if student marks in between 100 to 80 then grade is A
2. if student marks in between 79 to 60 then grade is B
3. if student marks in between 59 to 40 then grade is C
4. if student marks in between 39 to 25 then grade is D
5. if student marks in between 24 to 0 then grade is fail
6. if other than above marks expected output should be please enter correct marks!
"""

m=int(input("Enter your marks"))
if (m>=80 and m<=100):
   print("Your grade is A")
elif (m>=60 and m<=79):
   print("Your grade is B")
elif (m>=40 and m<=59):
   print("Your grade is C")
elif (m>=25 and m<=39):
    print("Your grade is D")
elif (m>=0 and m<=24):
   print("You failed")
else:
    print("please enter correct marks!")
# Out:
# Enter your marks 100
# Your grade is A

# %%
# write a program to find the largest number from three number
# write a program to find the leap year or non leap year
# write a program to check login credentials using conditional statements

a=int(input("Enter the number here"))
b=int(input("Enter the number here"))
c=int(input("Enter the number here"))
l=int
if (a >= b) and (a >= c):
    l=a
    print("The largest number is",l)
elif (b >= a) and (b >= c):
    l=b
    print("The largest number is",l)
else:
    l=c
    print("The largest number is",l)
# Out:
# Enter the number here 97870
# Enter the number here 889889
# Enter the number here 89789789
# The largest number is 89789789
